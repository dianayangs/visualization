# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
np.random.seed(613)
x = np.arange(50)
y = np.random.randint(0, 100,50)

# %%
fig,ax=plt.subplots(figsize=(5,3)) #we are specifying 2 objects using the subplot function
ax.scatter(x,y)

# %% [markdown]
# lecture: jan 22 2026 below

# %%
np.random.seed(613)
x = np.arange(50)
y1 = np.random.randint(0, 100,50)
y2 = np.random.randint(0,100,50)

# %%
fig,ax = plt.subplots(figsize=(5,3)) #creating the object
ax.plot(x,y1)
ax.plot(x,y2)
fig.show() #can also use plt.show()
# Out:
# /var/folders/3g/q27fgzvj5gg95ln82qygsp2c0000gn/T/ipykernel_3383/600659098.py:4: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
#adding labels and legend
fig,ax=plt.subplots(figsize=(5,3))
ax.plot(x,y1, label="Person 1")
ax.plot(x,y2, label = "Person 2")
ax.legend(loc='lower right',
        frameon = True, #add frame around the legend
        fontsize = 12, #change font size
        ncol = 2, #specify number of columns to make it horizontal instead of vertical stack
        shadow = True)
fig.show()
# Out:
# /var/folders/3g/q27fgzvj5gg95ln82qygsp2c0000gn/T/ipykernel_3383/604871800.py:10: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
#same as above but legend is outside
fig,ax=plt.subplots(figsize=(5,3))
ax.plot(x,y1, label="Person 1")
ax.plot(x,y2, label = "Person 2")
ax.legend(loc='upper left', #attaching upper left corner of legend to upper right corner of plot when used in conjuction with bbox_to_anchor() fxn
    bbox_to_anchor =(1, 1))
ax.text(10, 95, "This value is important!",
        ha='center', ##alignment of text
        color = 'red', ##modify font colour
        size = 20) ##modify font size #adding annotations with modifications
fig.show()
# Out:
# /var/folders/3g/q27fgzvj5gg95ln82qygsp2c0000gn/T/ipykernel_3383/3090116521.py:11: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# labelling scatter plot
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
ax.text(10, 95, "This value is important!",
ha='center', ##alignment of text
color = 'red', ##modify font colour
size = 20) ##modify font size
#fig.show()
# Out:
# Text(10, 95, 'This value is important!')
